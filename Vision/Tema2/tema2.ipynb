# %% [markdown]
# # Proiect 2 CAVA - Moroianu Theodor - 334

# %%
# Enable auto-reload of modules.
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload

# %%
# Import sources.
import sources.generate_dataset as generate_dataset
import sources.network_pytorch as network
import sources.solver as solver

# %%
# Solves the task, asuming that:
#   1. The model weigths (model/model.th) exist, or
#   2. There is a dataset available at network_dataset and outsider_dataset.
solver.solve("testare/simpsons_testare_scaled0.4/", "evaluare/fisiere_solutie/Moroianu_Theodor_334_testare/")
# Out:
# Processing images...
#   0%|          | 0/200 [00:00<?, ?it/s]
# Model loaded from memory!
# 100%|██████████| 200/200 [1:14:50<00:00, 22.45s/it]
# Sample detection: ('195.jpg', (((80, 10), (211, 141)), 0.9999999999999327))

# %%
# This trains the model.

# DO NOT RUN THIS!!!

network.train_model(lr=1e-5, NR_EPOCHS=30)

# %%
# This generates the dataset.

# DO NOT RUN THIS!!

generate_dataset.generate_dataset()

# %%
import sources.vizualize as viz

# %%
viz.vizualize("testare//")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-5b6476dc42a8> in <module>
# ----> 1 viz.vizualize("validare/simpsons_validare/")
#
# ~/Projects/ThirdYearCourses/Vision/Tema2/sources/vizualize.py in vizualize(input_path)
#      28
#      29     for im in imgs:
# ---> 30         preds = sliding_window.find_faces(im)
#      31
#      32         for b_box, prob in preds[-1]:
#
# ~/Projects/ThirdYearCourses/Vision/Tema2/sources/sliding_window.py in find_faces(img)
#      91             for xmin in range(0, img.shape[1] - window_dim + 1, stride):
#      92                 sliding_window = img[ymin:ymin+window_dim, xmin:xmin+window_dim, :]
# ---> 93                 labels = network.recognize_image(sliding_window)[0]
#      94
#      95                 process_window(xmin, ymin, xmin+window_dim-1, ymin+window_dim-1, labels)
#
# ~/Projects/ThirdYearCourses/Vision/Tema2/sources/network_pytorch.py in recognize_image(image)
#     233     image = image.reshape((1, constants.SIZE_FACE_MODEL, constants.SIZE_FACE_MODEL, 3))
#     234
# --> 235     preds = model(th.from_numpy(image).type(th.FloatTensor))
#     236     preds = F.softmax(preds, dim=1)
#     237
#
# ~/Software/anaconda3/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/Projects/ThirdYearCourses/Vision/Tema2/sources/network_pytorch.py in forward(self, x)
#      73     def forward(self, x):
#      74         x = x.permute(0, 3, 1, 2).to(dev)
# ---> 75         return self.net(x).cpu()
#      76
#      77
#
# ~/Software/anaconda3/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/Software/anaconda3/lib/python3.8/site-packages/torch/nn/modules/container.py in forward(self, input)
#     139     def forward(self, input):
#     140         for module in self:
# --> 141             input = module(input)
#     142         return input
#     143
#
# ~/Software/anaconda3/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/Software/anaconda3/lib/python3.8/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     444
#     445     def forward(self, input: Tensor) -> Tensor:
# --> 446         return self._conv_forward(input, self.weight, self.bias)
#     447
#     448 class Conv3d(_ConvNd):
#
# ~/Software/anaconda3/lib/python3.8/site-packages/torch/nn/modules/conv.py in _conv_forward(self, input, weight, bias)
#     440                             weight, bias, self.stride,
#     441                             _pair(0), self.dilation, self.groups)
# --> 442         return F.conv2d(input, weight, bias, self.stride,
#     443                         self.padding, self.dilation, self.groups)
#     444
#
# KeyboardInterrupt:
