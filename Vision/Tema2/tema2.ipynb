# %%
# Enable auto-reload of modules
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload

# %%
import sources.generate_dataset as g_d
import sources.constants as constants
import sources.network as network
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

# %%
bart = plt.imread("antrenare/bart/pic_0000.jpg")
bart = bart[273:378, 185:285, :]
plt.imshow(bart)

# %%
network.recognize_image(bart)
# Out:
# Model not found on disk.
# Generating training data...
# Loading dataset...
# Processing 1/4 - bart
# 100%|██████████| 1347/1347 [00:02<00:00, 514.18it/s]
# Processing 2/4 - homer
# 100%|██████████| 1462/1462 [00:03<00:00, 472.65it/s]
# Processing 3/4 - lisa
# 100%|██████████| 1313/1313 [00:02<00:00, 529.08it/s]
# Processing 4/4 - marge
# 100%|██████████| 1332/1332 [00:02<00:00, 545.65it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# Saving dataset...
# 100%|██████████| 6/6 [00:01<00:00,  3.09it/s]
# Training model...
# Epoch 1/20
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-70e207698c24> in <module>
# ----> 1 network.recognize_image(bart)
#
# ~/Projects/ThirdYearCourses/Vision/Tema2/sources/network.py in recognize_image(image)
#     122     global model
#     123
# --> 124     fit_model()
#     125
#     126     image = preprocess_image(image)
#
# ~/Projects/ThirdYearCourses/Vision/Tema2/sources/network.py in fit_model()
#      89
#      90     print("Training model...")
# ---> 91     model.fit(
#      92         X_train,
#      93         y_train,
#
# ~/Software/anaconda3/lib/python3.8/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# ~/Software/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py in autograph_handler(*args, **kwargs)
#    1127           except Exception as e:  # pylint:disable=broad-except
#    1128             if hasattr(e, "ag_error_metadata"):
# -> 1129               raise e.ag_error_metadata.to_exception(e)
#    1130             else:
#    1131               raise
#
# ValueError: in user code:
#
#     File "/home/theodor/Software/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 878, in train_function  *
#         return step_function(self, iterator)
#     File "/home/theodor/Software/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 867, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/home/theodor/Software/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 860, in run_step  **
#         outputs = model.train_step(data)
#     File "/home/theodor/Software/anaconda3/lib/python3.8/site-packages/keras/engine/training.py", line 809, in train_step
#         loss = self.compiled_loss(
#     File "/home/theodor/Software/anaconda3/lib/python3.8/site-packages/keras/engine/compile_utils.py", line 201, in __call__
#         loss_value = loss_obj(y_t, y_p, sample_weight=sw)
#     File "/home/theodor/Software/anaconda3/lib/python3.8/site-packages/keras/losses.py", line 141, in __call__
#         losses = call_fn(y_true, y_pred)
#     File "/home/theodor/Software/anaconda3/lib/python3.8/site-packages/keras/losses.py", line 245, in call  **
#         return ag_fn(y_true, y_pred, **self._fn_kwargs)
#     File "/home/theodor/Software/anaconda3/lib/python3.8/site-packages/keras/losses.py", line 1664, in categorical_crossentropy
#         return backend.categorical_crossentropy(
#     File "/home/theodor/Software/anaconda3/lib/python3.8/site-packages/keras/backend.py", line 4994, in categorical_crossentropy
#         target.shape.assert_is_compatible_with(output.shape)
#
#     ValueError: Shapes (None, 5) and (None, 10) are incompatible

# %%
for i in constants.SIM_LABEL_ORDER:
    print(i)
# Out:
# bart
# homer
# lisa
# marge
# unknown
# not_a_face

# %%
import con
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-eb1b1b26317d> in <module>
# ----> 1 import src.constants as a
#       2
#       3 import numpy as np
#       4 import cv2 as cv
#       5 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'src.constants'

# %%
img = 'antrenare/bart/pic_0003.jpg'
im = plt.imread(img)

# %%
import sfd.colors_simplifier as cs

# %%
im.shape
# Out:
# (368, 496, 3)

# %%
im_processed = cs.BYWO_to_RGB(cs.getBYWO(im))
plt.imshow(im_processed)
plt.show()
