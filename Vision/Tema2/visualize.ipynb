# %%
# Enable auto-reload of modules
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload

# %%
# import sources.vizualize as vizualize
import sources.network_pytorch as network
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np
import sources.generate_dataset as generate_dataset

# %%
x, y = generate_dataset.load_dataset()
# Out:
# 100%|██████████| 6/6 [00:15<00:00,  2.54s/it]
# Finished loading dataset...

# %%
len(x)
# Out:
# 78454

# %%
network.train_model(x, y)
# Out:
# Loading model to cuda
# Model could not be loaded! Training it...
# Epoch #0:
# Train...
# 100%|██████████| 1042/1042 [00:44<00:00, 23.58it/s]
# Average train loss: 0.6144300403641877, average train accuracy: 0.8108468404658239
# Eval...
# 100%|██████████| 184/184 [00:01<00:00, 129.39it/s]
# Average test loss: 0.3026457963835286, average test accuracy: 0.9104542097319728
# Epoch #1:
# Train...
# 100%|██████████| 1042/1042 [00:43<00:00, 23.91it/s]
# Average train loss: 0.2862738970802979, average train accuracy: 0.9027689008360403
# Eval...
# 100%|██████████| 184/184 [00:01<00:00, 128.04it/s]
# Average test loss: 0.20645997691494616, average test accuracy: 0.9325330140797988
# Epoch #2:
# Train...
# 100%|██████████| 1042/1042 [00:44<00:00, 23.64it/s]
# Average train loss: 0.2141513966181228, average train accuracy: 0.9256508409290534
# Eval...
# 100%|██████████| 184/184 [00:01<00:00, 129.02it/s]
# Average test loss: 0.18224839340773938, average test accuracy: 0.9398255743410276
# ...

# %%
im = plt.imread("antrenare/bart/pic_1081.jpg")
im = cv.cvtColor(im, cv.COLOR_RGB2HLS)

mask = np.zeros(im.shape[:2])

for i in range(im.shape[0]):
    for j in range(im.shape[1]):
        val = im[i][j][0]
        if not (10 < val < 50):
            mask[i][j] = 0
        else:
            mask[i][j] = 255

plt.imshow(mask)
plt.show()

# %%
network.train_model()
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /home/theodor/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 109MB/s]
# Model could not be loaded!
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-2f3bc47808d6> in <module>
# ----> 1 network.train_model()
#
# ~/Projects/ThirdYearCourses/Vision/Tema2/sources/network_pytorch.py in train_model()
#      70     X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.15, random_state= 21)
#      71
# ---> 72     train_dataset = th.utils.TensorDataset(th.from_numpy(X_train), th.from_numpy(y_train))
#      73     test_dataset = th.utils.TensorDataset(th.from_numpy(X_test), th.from_numpy(y_test))
#      74
#
# AttributeError: module 'torch.utils' has no attribute 'TensorDataset'

# %%
for i in range(10):
    vizualize.vizualize("validare/")
# Out:
# Intersection Over Reunion: 0.0
# Probability: 0.5088989278301597
# Probability: 0.37967780232429504
# Probability: 0.2008755151182413
# Probability: 0.10400166362524033
# Probability: 0.09041481651365757
# Intersection Over Reunion: 0.5833333333333334
# Probability: 0.22289280220866203
# Probability: 0.1756860762834549
# Probability: 0.06874484196305275
# Intersection Over Reunion: 0.39830834294502115
# Probability: 0.6585602946579456
# Probability: 0.08533474802970886
# Intersection Over Reunion: 0.1342031686859273
# Probability: 0.31006333231925964
# Probability: 0.10264875856228173
# Probability: 0.09882311004912481
# Intersection Over Reunion: 0.7108540925266904
# Probability: 0.3493121936917305
# Probability: 0.18382382951676846
# Probability: 0.12761026993393898
# Probability: 0.0247282637283206
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ...
