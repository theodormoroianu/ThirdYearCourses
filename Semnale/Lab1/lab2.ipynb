# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.io.wavfile as wf
import scipy.signal as sg
import math
from scipy.ndimage.filters import gaussian_filter

# %%
rate, x = wf.read('sound.wav')
f,t,s = sg.spectrogram(x, fs=rate)

im = 10*np.log10(s)
im = im / 2 + gaussian_filter(im, sigma=3) / 2

mid = (2 * np.max(im) + np.min(im)) / 3
# im[im < mid] = 0

fig = plt.figure()
plt.pcolormesh(t, f, im, shading='gouraud')
plt.ylabel('Frequency [Hz]')
plt.xlabel('Time [sec]')

plt.show()

# %%
im = 10*np.log10(s)
im = im - gaussian_filter(im, sigma=3)

mid = (2 * np.max(im) + np.min(im)) / 3
im[im < mid] = 0


plt.imshow(im)
plt.show()
